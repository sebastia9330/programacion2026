# %% [markdown]
# #Instalar librerias

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.2.7
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##Configurar el dotenv

# %%
import os 
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv('./KEY.env')#buscar con nombre
# Out:
# False

# %%
load_dotenv(find_dotenv(), override= True)# buscar sin nombre
# Out:
# True

# %%
os.environ.get('OPEN_API_KEY')

# %% [markdown]
# LLM NODELS (GPT3.5)

# %%
from langchain_openai import OpenAI

# %%
gpt3 = OpenAI(model_name='gpt-3.5-turbo-instruct', temperature=0.7, max_tokens=1024)

# %%
print(gpt3)
# Out:
# OpenAI
# Params: {'model_name': 'gpt-3.5-turbo-instruct', 'temperature': 0.7, 'top_p': 1, 'frequency_penalty': 0, 'presence_penalty': 0, 'n': 1, 'seed': None, 'logprobs': None, 'max_tokens': 1024}

# %%
respuesta = gpt3.invoke("Explica qué es un modelo de IA LLM")

# %%
print(respuesta)
# Out:
# Un modelo de IA LLM (Learning, Language, and Memory) es un tipo de modelo de inteligencia artificial que se enfoca en el aprendizaje, el lenguaje y la memoria. Este tipo de modelo está basado en la idea de que el aprendizaje y el lenguaje son fundamentales para la inteligencia, y que la memoria es esencial para el almacenamiento y recuperación de la información aprendida.
#
# El objetivo de un modelo de IA LLM es simular la forma en que los seres humanos aprenden, procesan el lenguaje y utilizan la memoria para resolver problemas y tomar decisiones. Para lograr esto, el modelo se basa en algoritmos de aprendizaje automático y procesamiento del lenguaje natural para analizar grandes cantidades de datos y aprender patrones y reglas.
#
# El aprendizaje en un modelo de IA LLM se basa en la capacidad de adaptarse y mejorar a medida que se le proporciona más información. Esto le permite al modelo aprender a realizar tareas específicas, como el reconocimiento de patrones en imágenes o la traducción de idiomas.
#
# El lenguaje es una parte importante de este tipo de modelo, ya que le permite al sistema comunicarse y entender la información que se le proporciona. Esto incluye no solo la capacidad de procesar y comprender el lenguaje humano, sino también la capacidad de generar lenguaje de manera efectiva.
#
# Por último, la memoria juega un papel fundamental en un modelo de IA LLM al permitirle almacenar y recuperar información relevante para la realización de tareas y la toma de decisiones. Esto incluye tanto la memoria a corto plazo como la memoria a largo plazo.
#
# En resumen, un modelo de IA LLM es un enfoque de inteligencia artificial que se basa en el aprendizaje, el lenguaje y la memoria para simular la inteligencia humana y realizar tareas complejas.

# %%
respuestas = gpt3.generate(['Cual es la capital de colombia',
                            'que es oracle',
                            'se puede conectar un llm a oracle'])

# %%
print(respuestas)
# Out:
# generations=[[Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nOracle es una empresa de tecnología fundada en 1977 que se dedica a la creación y venta de software y hardware de gestión de bases de datos, sistemas de gestión de información, soluciones en la nube, aplicaciones empresariales y servicios relacionados. Es una de las empresas líderes en el mercado de bases de datos y ofrece soluciones para diferentes industrias y sectores, incluyendo finanzas, comercio, telecomunicaciones, salud, entre otros. Oracle también es conocida por su lenguaje de programación SQL y su sistema operativo Oracle Solaris.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text=' 12c\n\nSí, se puede conectar un LLM (Logical Link Manager) a una base de datos Oracle 12c. Para ello, se deben seguir los siguientes pasos:\n\n1. Instalar el software de Oracle 12c en la máquina donde se encuentra el LLM.\n\n2. Crear una instancia de la base de datos Oracle 12c.\n\n3. Configurar el archivo tnsnames.ora con la información de la instancia de la base de datos Oracle 12c.\n\n4. Configurar el archivo listener.ora para que el LLM pueda conectarse a la base de datos Oracle 12c.\n\n5. Configurar el LLM para que utilice el driver de Oracle 12c para conectarse a la base de datos.\n\n6. Probar la conexión entre el LLM y la base de datos Oracle 12c.\n\nEs importante asegurarse de que el LLM y la base de datos Oracle 12c se encuentren en la misma red y que la configuración de red permita la comunicación entre ellos. También es recomendable seguir las instrucciones específicas del fabricante del LLM para configurar la conexión con la base de datos Oracle 12c.', generation_info={'finish_reason': 'stop', 'logprobs': None})]] llm_output={'token_usage': {'prompt_tokens': 19, 'total_tokens': 408, 'completion_tokens': 389}, 'model_name': 'gpt-3.5-turbo-instruct'} run=[RunInfo(run_id=UUID('019c0aa1-b5ba-7601-8636-afb0b4a6e4e0')), RunInfo(run_id=UUID('019c0aa1-b5ba-7601-8636-afc31fee0c22')), RunInfo(run_id=UUID('019c0aa1-b5ba-7601-8636-afdfb1bd3c84'))] type='LLMResult'

# %%
print(respuestas.generations)
# Out:
# [[Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nOracle es una empresa de tecnología fundada en 1977 que se dedica a la creación y venta de software y hardware de gestión de bases de datos, sistemas de gestión de información, soluciones en la nube, aplicaciones empresariales y servicios relacionados. Es una de las empresas líderes en el mercado de bases de datos y ofrece soluciones para diferentes industrias y sectores, incluyendo finanzas, comercio, telecomunicaciones, salud, entre otros. Oracle también es conocida por su lenguaje de programación SQL y su sistema operativo Oracle Solaris.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text=' 12c\n\nSí, se puede conectar un LLM (Logical Link Manager) a una base de datos Oracle 12c. Para ello, se deben seguir los siguientes pasos:\n\n1. Instalar el software de Oracle 12c en la máquina donde se encuentra el LLM.\n\n2. Crear una instancia de la base de datos Oracle 12c.\n\n3. Configurar el archivo tnsnames.ora con la información de la instancia de la base de datos Oracle 12c.\n\n4. Configurar el archivo listener.ora para que el LLM pueda conectarse a la base de datos Oracle 12c.\n\n5. Configurar el LLM para que utilice el driver de Oracle 12c para conectarse a la base de datos.\n\n6. Probar la conexión entre el LLM y la base de datos Oracle 12c.\n\nEs importante asegurarse de que el LLM y la base de datos Oracle 12c se encuentren en la misma red y que la configuración de red permita la comunicación entre ellos. También es recomendable seguir las instrucciones específicas del fabricante del LLM para configurar la conexión con la base de datos Oracle 12c.', generation_info={'finish_reason': 'stop', 'logprobs': None})]]

# %%
print(respuestas.generations[0])
# Out:
# [Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})]

# %%
print(respuestas.generations[0][0])
# Out:
# text='\n\nLa capital de Colombia es Bogotá.' generation_info={'finish_reason': 'stop', 'logprobs': None}

# %%
print(respuestas.generations[0][0].text)
# Out:
# La capital de Colombia es Bogotá.

# %%
print(respuestas.generations[1][0].text)
# Out:
# Oracle es una empresa de tecnología fundada en 1977 que se dedica a la creación y venta de software y hardware de gestión de bases de datos, sistemas de gestión de información, soluciones en la nube, aplicaciones empresariales y servicios relacionados. Es una de las empresas líderes en el mercado de bases de datos y ofrece soluciones para diferentes industrias y sectores, incluyendo finanzas, comercio, telecomunicaciones, salud, entre otros. Oracle también es conocida por su lenguaje de programación SQL y su sistema operativo Oracle Solaris.

# %%
print(respuestas.generations[2][0].text)
# Out:
#  12c
#
# Sí, se puede conectar un LLM (Logical Link Manager) a una base de datos Oracle 12c. Para ello, se deben seguir los siguientes pasos:
#
# 1. Instalar el software de Oracle 12c en la máquina donde se encuentra el LLM.
#
# 2. Crear una instancia de la base de datos Oracle 12c.
#
# 3. Configurar el archivo tnsnames.ora con la información de la instancia de la base de datos Oracle 12c.
#
# 4. Configurar el archivo listener.ora para que el LLM pueda conectarse a la base de datos Oracle 12c.
#
# 5. Configurar el LLM para que utilice el driver de Oracle 12c para conectarse a la base de datos.
#
# 6. Probar la conexión entre el LLM y la base de datos Oracle 12c.
#
# Es importante asegurarse de que el LLM y la base de datos Oracle 12c se encuentren en la misma red y que la configuración de red permita la comunicación entre ellos. También es recomendable seguir las instrucciones específicas del fabricante del LLM para configurar la conexión con la base de datos Oracle 12c.
