# %% [markdown]
# #Instalar librerias

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.2.7
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.7
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %% [markdown]
# ##Configurar el dotenv

# %%
import os 
from dotenv import load_dotenv, find_dotenv
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
load_dotenv('./KEY.env')#buscar con nombre
# Out:
# False
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
load_dotenv(find_dotenv(), override= True)# buscar sin nombre
# Out:
# True
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
os.environ.get('OPEN_API_KEY')
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %% [markdown]
# LLM NODELS (GPT3.5)

# %%
from langchain_openai import OpenAI
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
gpt3 = OpenAI(model_name='gpt-3.5-turbo-instruct', temperature=0.7, max_tokens=1024)
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
print(gpt3)
# Out:
# OpenAI
# Params: {'model_name': 'gpt-3.5-turbo-instruct', 'temperature': 0.7, 'top_p': 1, 'frequency_penalty': 0, 'presence_penalty': 0, 'n': 1, 'seed': None, 'logprobs': None, 'max_tokens': 1024}
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
respuesta = gpt3.invoke("Explica qué es un modelo de IA LLM")
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
print(respuesta)
# Out:
# Un modelo de IA LLM (aprendizaje profundo del lenguaje) es un enfoque de aprendizaje automático que utiliza redes neuronales profundas para procesar y comprender el lenguaje humano. Estos modelos se basan en la idea de que el lenguaje humano se puede descomponer en unidades más pequeñas, como palabras y oraciones, y que estas unidades se pueden representar matemáticamente como vectores en un espacio multidimensional.
#
# El objetivo de un modelo de IA LLM es enseñar a una máquina a comprender y generar lenguaje humano de manera similar a como lo hacen los humanos. Para ello, se entrena al modelo con grandes cantidades de datos de lenguaje humano, como textos, conversaciones o subtítulos de videos, para que aprenda las reglas y patrones del lenguaje.
#
# ...

# %%
respuestas = gpt3.generate(['Cual es la capital de colombia',
                            'que es oracle',
                            'se puede conectar un llm a oracle'])
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
print(respuestas)
# Out:
# generations=[[Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nOracle es una empresa de tecnología fundada en 1977 por Larry Ellison, Bob Miner y Ed Oates. Es conocida principalmente por su sistema de gestión de bases de datos, Oracle Database, que es utilizado por grandes empresas y organizaciones en todo el mundo.\n\nAdemás de su sistema de bases de datos, Oracle también ofrece una amplia gama de productos y servicios relacionados con la gestión de datos, la nube, la inteligencia artificial, el análisis de datos, la seguridad y la gestión de aplicaciones empresariales.\n\nOracle es una de las empresas líderes en el mercado de software empresarial y es considerada como una de las pioneras en el desarrollo de tecnologías de bases de datos y aplicaciones empresariales. Su objetivo es ayudar a las empresas a gestionar y utilizar sus datos de manera eficiente para impulsar su crecimiento y éxito
# ...

# %%
print(respuestas.generations)
# Out:
# [[Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nOracle es una empresa de tecnología fundada en 1977 por Larry Ellison, Bob Miner y Ed Oates. Es conocida principalmente por su sistema de gestión de bases de datos, Oracle Database, que es utilizado por grandes empresas y organizaciones en todo el mundo.\n\nAdemás de su sistema de bases de datos, Oracle también ofrece una amplia gama de productos y servicios relacionados con la gestión de datos, la nube, la inteligencia artificial, el análisis de datos, la seguridad y la gestión de aplicaciones empresariales.\n\nOracle es una de las empresas líderes en el mercado de software empresarial y es considerada como una de las pioneras en el desarrollo de tecnologías de bases de datos y aplicaciones empresariales. Su objetivo es ayudar a las empresas a gestionar y utilizar sus datos de manera eficiente para impulsar su crecimiento y éxito en la era d
# ...

# %%
print(respuestas.generations[0])
# Out:
# [Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})]
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
print(respuestas.generations[0][0])
# Out:
# text='\n\nLa capital de Colombia es Bogotá.' generation_info={'finish_reason': 'stop', 'logprobs': None}
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
print(respuestas.generations[0][0].text)
# Out:
# La capital de Colombia es Bogotá.
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
print(respuestas.generations[1][0].text)
# Out:
# Oracle es una empresa de tecnología fundada en 1977 por Larry Ellison, Bob Miner y Ed Oates. Es conocida principalmente por su sistema de gestión de bases de datos, Oracle Database, que es utilizado por grandes empresas y organizaciones en todo el mundo.
#
# Además de su sistema de bases de datos, Oracle también ofrece una amplia gama de productos y servicios relacionados con la gestión de datos, la nube, la inteligencia artificial, el análisis de datos, la seguridad y la gestión de aplicaciones empresariales.
#
# Oracle es una de las empresas líderes en el mercado de software empresarial y es considerada como una de las pioneras en el desarrollo de tecnologías de bases de datos y aplicaciones empresariales. Su objetivo es ayudar a las empresas a gestionar y utilizar sus datos de manera eficiente para impulsar su crecimiento y éxito en la era digital.
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
print(respuestas.generations[2][0].text)
# Out:
# Sí, es posible conectar un LLM (Lenguaje de Manipulación de Datos) a una base de datos Oracle. Para ello, se pueden seguir los siguientes pasos:
#
# 1. Instalar un cliente de Oracle: Para poder conectarse a una base de datos Oracle, es necesario tener instalado un cliente de Oracle en el sistema donde se ejecutará el LLM. Este cliente contiene los controladores y librerías necesarios para realizar la conexión con la base de datos.
#
# 2. Configurar el cliente de Oracle: Una vez instalado el cliente de Oracle, es necesario configurarlo para establecer la conexión con la base de datos. Esto se puede hacer a través de un archivo de configuración o mediante la configuración del cliente gráfico.
#
# 3. Importar la librería JDBC: La mayoría de los LLM utilizan la interfaz JDBC (Java Database Connectivity) para conectarse a una base de datos. Por lo tanto, es necesario importar la librería JDBC de Oracle en el código del LLM para poder utilizarla.
#
# ...

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
chat = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.5, max_tokens=1024)
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
mensajes = [
    SystemMessage(content = 'Eres un experto en ingenieria de datos y quieres ser mi maestro'),
    HumanMessage(content = 'Escribe los pasos mas importantes para ser el mejor ingeniero de datos del mundo y ser un referente en la materia')
]
respuesta = chat.invoke(mensajes)
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
respuesta
# Out:
# AIMessage(content='Para convertirte en un experto en ingeniería de datos y ser un referente en la materia, aquí tienes algunos pasos importantes a seguir:\n\n1. **Formación académica sólida**: Obtener una educación formal en ciencias de la computación, ingeniería de software, matemáticas o campos relacionados es fundamental para comprender los fundamentos de la ingeniería de datos.\n\n2. **Dominio de herramientas y tecnologías**: Familiarízate con las herramientas y tecnologías más utilizadas en el campo de la ingeniería de datos, como bases de datos relacionales y no relacionales, lenguajes de programación como Python y R, frameworks como Apache Hadoop y Apache Spark, entre otros.\n\n3. **Experiencia práctica**: Aplica tus conocimientos en proyectos reales para adquirir experiencia práctica. Participa en desafíos de ciencia de datos, contribuye a proyectos de código abierto o busca oportunidades laborales que te permitan trabajar en proyectos de ingeniería de datos.\n\n4. **Desarrol
# ...

# %%
respuesta.content
# Out:
# 'Para convertirte en un experto en ingeniería de datos y ser un referente en la materia, aquí tienes algunos pasos importantes a seguir:\n\n1. **Formación académica sólida**: Obtener una educación formal en ciencias de la computación, ingeniería de software, matemáticas o campos relacionados es fundamental para comprender los fundamentos de la ingeniería de datos.\n\n2. **Dominio de herramientas y tecnologías**: Familiarízate con las herramientas y tecnologías más utilizadas en el campo de la ingeniería de datos, como bases de datos relacionales y no relacionales, lenguajes de programación como Python y R, frameworks como Apache Hadoop y Apache Spark, entre otros.\n\n3. **Experiencia práctica**: Aplica tus conocimientos en proyectos reales para adquirir experiencia práctica. Participa en desafíos de ciencia de datos, contribuye a proyectos de código abierto o busca oportunidades laborales que te permitan trabajar en proyectos de ingeniería de datos.\n\n4. **Desarrollo de habilidades 
# ...

# %% [markdown]
# ##Prompt Templates

# %%
from langchain_core.prompts import PromptTemplate
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
#Creacion de una plantilla de prompt
plantilla = """
    Escribe un mensaje de felicitacion para {nombre} en su {ocasion}
"""
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
prompt = PromptTemplate(
    input_variables=['nombre', 'ocasion'],
    template=plantilla
)
# Out:
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
print(prompt)
# Out:
# input_variables=['nombre', 'ocasion'] input_types={} partial_variables={} template='\n    Escribe un mensaje de felicitacion para {nombre} en su {ocasion}\n'
# notebook controller is DISPOSED.
#
# Vea el [registro] de Jupyter (command:jupyter.viewOutput) para obtener más detalles.

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.5, max_tokens=1024)
respuesta = llm.invoke(prompt.format(nombre='Sebastian', ocasion='Tristeza'))
print(respuesta.content)
# Out:
# Querido Sebastian, sé que estás pasando por un momento difícil y quiero que sepas que estoy aquí para ti. Aunque la tristeza pueda parecer abrumadora en este momento, recuerda que siempre habrá luz al final del túnel. Eres una persona fuerte y valiente, y estoy seguro de que saldrás de esta situación más fuerte que nunca. ¡No estás solo en esto! ¡Mucho ánimo y fuerza, querido amigo!
