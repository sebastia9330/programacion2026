# %% [markdown]
# #Instalar librerias

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.2.10
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.10

# %% [markdown]
# ##Configurar el dotenv

# %%
import os 
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv('./KEY.env')#buscar con nombre
# Out:
# False

# %%
load_dotenv(find_dotenv(), override= True)# buscar sin nombre
# Out:
# True

# %%
os.environ.get('OPEN_API_KEY')

# %% [markdown]
# LLM NODELS (GPT3.5)

# %%
from langchain_openai import OpenAI

# %%
gpt3 = OpenAI(model_name='gpt-3.5-turbo-instruct', temperature=0.7, max_tokens=1024)

# %%
print(gpt3)
# Out:
# OpenAI
# Params: {'model_name': 'gpt-3.5-turbo-instruct', 'temperature': 0.7, 'top_p': 1, 'frequency_penalty': 0, 'presence_penalty': 0, 'n': 1, 'seed': None, 'logprobs': None, 'max_tokens': 1024}

# %%
respuesta = gpt3.invoke("Explica qué es un modelo de IA LLM")

# %%
print(respuesta)
# Out:
# Un modelo de IA LLM (Learning, Language, and Memory) es un tipo de modelo de inteligencia artificial que se enfoca en el aprendizaje, el lenguaje y la memoria. Este tipo de modelo se basa en la idea de que el aprendizaje humano se puede imitar y mejorar mediante algoritmos y técnicas de inteligencia artificial.
#
# El modelo de IA LLM se divide en tres componentes principales: aprendizaje, lenguaje y memoria. El aprendizaje se refiere al proceso de adquirir nuevos conocimientos y habilidades a través de la experiencia, mientras que el lenguaje se refiere a la capacidad de entender y utilizar el lenguaje humano. La memoria se refiere a la capacidad de almacenar y recuperar información.
#
# El modelo de IA LLM utiliza algoritmos de aprendizaje automático para analizar grandes cantidades de datos y aprender patrones y reglas. Estos algoritmos pueden ser supervisados (con datos etiquetados) o no supervisados (sin datos etiquetados) y pueden utilizarse para tareas de clasificación, predicción o reconocimiento de patrones.
#
# El componente de lenguaje del modelo de IA LLM se basa en técnicas de procesamiento del lenguaje natural (PLN) que permiten que una máquina comprenda y genere lenguaje humano. Estas técnicas incluyen el análisis sintáctico, la generación de lenguaje y el reconocimiento de voz.
#
# Por último, el componente de memoria del modelo de IA LLM se basa en técnicas de memoria a largo plazo (LTM) que permiten que una máquina almacene y recupere información de manera similar a como lo hace el cerebro humano. Esto le permite al modelo recordar información y utilizarla en tareas futuras.
#
# En resumen, un modelo de IA LLM es un enfoque de inteligencia artificial que combina el aprendizaje automático, el procesamiento del lenguaje natural y la memoria a largo plazo para imitar y mejorar el aprendizaje, el lenguaje y la memoria humanos. Este tipo de modelo se utiliza en una amplia gama de aplicaciones, como el procesamiento de lenguaje, la traducción automática, la conversión de voz a texto y la toma de decisiones.

# %%
respuestas = gpt3.generate(['Cual es la capital de colombia',
                            'que es oracle',
                            'se puede conectar un llm a oracle'])

# %%
print(respuestas)
# Out:
# generations=[[Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nOracle es una empresa de tecnología especializada en el desarrollo y comercialización de sistemas de gestión de bases de datos, aplicaciones empresariales y servicios en la nube. Su principal producto es Oracle Database, un sistema de gestión de bases de datos relacional que es utilizado por empresas y organizaciones de todo el mundo para almacenar y gestionar grandes cantidades de información. Además, Oracle ofrece una amplia gama de productos y servicios en diferentes áreas de la tecnología, como aplicaciones empresariales, sistemas de almacenamiento de datos, herramientas de desarrollo de software, servicios en la nube y hardware de servidores. Oracle es una de las empresas líderes en el mercado de tecnología y cuenta con clientes en más de 175 países. ', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nSí, se puede conectar un LLM (Logical Link Manager) a Oracle utilizando un controlador JDBC (Java Database Connectivity). El LLM se conectará al controlador JDBC, que a su vez se conectará a la base de datos Oracle. Esto permitirá al LLM acceder y manipular los datos almacenados en la base de datos Oracle.', generation_info={'finish_reason': 'stop', 'logprobs': None})]] llm_output={'token_usage': {'prompt_tokens': 19, 'completion_tokens': 243, 'total_tokens': 262}, 'model_name': 'gpt-3.5-turbo-instruct'} run=[RunInfo(run_id=UUID('019cd317-d968-79e1-a4ae-95add51bf2ca')), RunInfo(run_id=UUID('019cd317-d968-79e1-a4ae-95b44387c913')), RunInfo(run_id=UUID('019cd317-d968-79e1-a4ae-95c7df03c596'))] type='LLMResult'

# %%
print(respuestas.generations)
# Out:
# [[Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nOracle es una empresa de tecnología especializada en el desarrollo y comercialización de sistemas de gestión de bases de datos, aplicaciones empresariales y servicios en la nube. Su principal producto es Oracle Database, un sistema de gestión de bases de datos relacional que es utilizado por empresas y organizaciones de todo el mundo para almacenar y gestionar grandes cantidades de información. Además, Oracle ofrece una amplia gama de productos y servicios en diferentes áreas de la tecnología, como aplicaciones empresariales, sistemas de almacenamiento de datos, herramientas de desarrollo de software, servicios en la nube y hardware de servidores. Oracle es una de las empresas líderes en el mercado de tecnología y cuenta con clientes en más de 175 países. ', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nSí, se puede conectar un LLM (Logical Link Manager) a Oracle utilizando un controlador JDBC (Java Database Connectivity). El LLM se conectará al controlador JDBC, que a su vez se conectará a la base de datos Oracle. Esto permitirá al LLM acceder y manipular los datos almacenados en la base de datos Oracle.', generation_info={'finish_reason': 'stop', 'logprobs': None})]]

# %%
print(respuestas.generations[0])
# Out:
# [Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})]

# %%
print(respuestas.generations[0][0])
# Out:
# text='\n\nLa capital de Colombia es Bogotá.' generation_info={'finish_reason': 'stop', 'logprobs': None}

# %%
print(respuestas.generations[0][0].text)
# Out:
# La capital de Colombia es Bogotá.

# %%
print(respuestas.generations[1][0].text)
# Out:
# Oracle es una empresa de tecnología especializada en el desarrollo y comercialización de sistemas de gestión de bases de datos, aplicaciones empresariales y servicios en la nube. Su principal producto es Oracle Database, un sistema de gestión de bases de datos relacional que es utilizado por empresas y organizaciones de todo el mundo para almacenar y gestionar grandes cantidades de información. Además, Oracle ofrece una amplia gama de productos y servicios en diferentes áreas de la tecnología, como aplicaciones empresariales, sistemas de almacenamiento de datos, herramientas de desarrollo de software, servicios en la nube y hardware de servidores. Oracle es una de las empresas líderes en el mercado de tecnología y cuenta con clientes en más de 175 países.

# %%
print(respuestas.generations[2][0].text)
# Out:
# Sí, se puede conectar un LLM (Logical Link Manager) a Oracle utilizando un controlador JDBC (Java Database Connectivity). El LLM se conectará al controlador JDBC, que a su vez se conectará a la base de datos Oracle. Esto permitirá al LLM acceder y manipular los datos almacenados en la base de datos Oracle.

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

# %%
chat = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.5, max_tokens=1024)

# %%
mensajes = [
    SystemMessage(content = 'Eres un experto en ingenieria de datos y quieres ser mi maestro'),
    HumanMessage(content = 'Escribe los pasos mas importantes para ser el mejor ingeniero de datos del mundo y ser un referente en la materia')
]
respuesta = chat.invoke(mensajes)

# %%
respuesta
# Out:
# AIMessage(content='Para convertirte en un experto en ingeniería de datos y ser un referente en la materia, es importante seguir estos pasos clave:\n\n1. **Educación y formación continua:** Obtén una sólida base educativa en ciencias de la computación, matemáticas, estadística o áreas relacionadas. Realiza cursos, certificaciones y capacitaciones continuas en tecnologías y herramientas de ingeniería de datos.\n\n2. **Dominio de herramientas y tecnologías:** Familiarízate y domina las herramientas y tecnologías clave en el campo de la ingeniería de datos, como bases de datos relacionales y no relacionales, lenguajes de programación como Python y R, frameworks de big data como Hadoop y Spark, entre otros.\n\n3. **Experiencia práctica:** Aplica tus conocimientos en proyectos reales. Trabaja en proyectos de ingeniería de datos que te permitan enfrentarte a desafíos reales y desarrollar habilidades prácticas en la manipulación y análisis de datos a gran escala.\n\n4. **Desarrollo de habilidades blandas:** Además de habilidades técnicas, es importante desarrollar habilidades blandas como trabajo en equipo, comunicación efectiva, resolución de problemas y pensamiento crítico. Estas habilidades te ayudarán a colaborar con otros profesionales y liderar proyectos de manera efectiva.\n\n5. **Networking:** Construye una red de contactos en la industria de la ingeniería de datos. Participa en conferencias, eventos y comunidades en línea para conocer a otros profesionales del campo, intercambiar conocimientos y estar al tanto de las últimas tendencias y avances en la industria.\n\n6. **Mantente actualizado:** La tecnología y las herramientas en el campo de la ingeniería de datos evolucionan constantemente. Mantente actualizado con las últimas tendencias, investigaciones y avances en el campo para seguir mejorando tus habilidades y conocimientos.\n\nSiguiendo estos pasos y manteniendo un enfoque en el aprendizaje continuo y la mejora constante, podrás convertirte en un experto en ingeniería de datos y ser un referente en la materia. ¡Buena suerte en tu camino hacia la excelencia en este campo tan apasionante!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 509, 'prompt_tokens': 53, 'total_tokens': 562, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DHWHxHuvdx7G6dQlHl7MO6R71idTh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cd317-f5f1-7c03-ad7f-0e78c9b813ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 509, 'total_tokens': 562, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
respuesta.content
# Out:
# 'Para convertirte en un experto en ingeniería de datos y ser un referente en la materia, es importante seguir estos pasos clave:\n\n1. **Educación y formación continua:** Obtén una sólida base educativa en ciencias de la computación, matemáticas, estadística o áreas relacionadas. Realiza cursos, certificaciones y capacitaciones continuas en tecnologías y herramientas de ingeniería de datos.\n\n2. **Dominio de herramientas y tecnologías:** Familiarízate y domina las herramientas y tecnologías clave en el campo de la ingeniería de datos, como bases de datos relacionales y no relacionales, lenguajes de programación como Python y R, frameworks de big data como Hadoop y Spark, entre otros.\n\n3. **Experiencia práctica:** Aplica tus conocimientos en proyectos reales. Trabaja en proyectos de ingeniería de datos que te permitan enfrentarte a desafíos reales y desarrollar habilidades prácticas en la manipulación y análisis de datos a gran escala.\n\n4. **Desarrollo de habilidades blandas:** Además de habilidades técnicas, es importante desarrollar habilidades blandas como trabajo en equipo, comunicación efectiva, resolución de problemas y pensamiento crítico. Estas habilidades te ayudarán a colaborar con otros profesionales y liderar proyectos de manera efectiva.\n\n5. **Networking:** Construye una red de contactos en la industria de la ingeniería de datos. Participa en conferencias, eventos y comunidades en línea para conocer a otros profesionales del campo, intercambiar conocimientos y estar al tanto de las últimas tendencias y avances en la industria.\n\n6. **Mantente actualizado:** La tecnología y las herramientas en el campo de la ingeniería de datos evolucionan constantemente. Mantente actualizado con las últimas tendencias, investigaciones y avances en el campo para seguir mejorando tus habilidades y conocimientos.\n\nSiguiendo estos pasos y manteniendo un enfoque en el aprendizaje continuo y la mejora constante, podrás convertirte en un experto en ingeniería de datos y ser un referente en la materia. ¡Buena suerte en tu camino hacia la excelencia en este campo tan apasionante!'

# %% [markdown]
# ##Prompt Templates

# %%
from langchain_core.prompts import PromptTemplate

# %%
#Creacion de una plantilla de prompt
plantilla = """
    Escribe un mensaje de felicitacion para {nombre} en su {ocasion}
"""

# %%
prompt = PromptTemplate(
    input_variables=['nombre', 'ocasion'],
    template=plantilla
)

# %%
print(prompt)
# Out:
# input_variables=['nombre', 'ocasion'] input_types={} partial_variables={} template='\n    Escribe un mensaje de felicitacion para {nombre} en su {ocasion}\n'

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.5, max_tokens=1024)
respuesta = llm.invoke(prompt.format(nombre='Sebastian', ocasion='Tristeza'))
print(respuesta.content)
# Out:
# Querido Sebastian, sé que estás pasando por un momento difícil y lleno de tristeza en este momento. Quiero recordarte que eres una persona increíblemente fuerte y valiente, y que esta tristeza que sientes ahora no durará para siempre. Estoy aquí para apoyarte en todo momento y para recordarte lo especial que eres. ¡Ánimo y fuerza, querido amigo! Juntos superaremos esta tristeza y saldremos más fuertes que nunca. ¡Te envío un abrazo lleno de cariño y apoyo!

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough

# %%
modelo1 = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.7, max_tokens=1024)
plantilla = """
    Escriba los puntos mas importantes para {tema}
"""

# %%
prompt = PromptTemplate(
    input_variables = ['tema'],
    template = plantilla
)

cadena1 = prompt | modelo1

# %%
modelo2 = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=1.2, max_tokens=1024)
plantilla2 = """
    Necesito que seas un experto guionista y creador de contenido para redes sociales como youtube, necesito 
    que me hagas el script completo para youtube sobre este tema, necesito explicar todo con lujo de detalle:
    {puntos}
"""

# %%
prompt2 = PromptTemplate(
    input_variables = ['puntos'],
    template = plantilla2
)

cadena2 = prompt2 | modelo2

# %%
modelo3 = ChatOpenAI(model_name='gpt-4', temperature=1.2, max_tokens=1024)
plantilla3 = '''
    Necesito que seas un experto en SEO, necesito que bajo todo el conocimiento de Youtube que tienes me
    hagas un titulo (100 caracteres incluyendo espacios) y una descripcion (entre 4000 a 5000 caracteres)
    , no anotes los numeros de caracteres, para el script anterior. Que el titulo este en forma de pregunta
    con base a como por ejemplo: ¿cómo vender mas? {script}
'''

# %%
prompt3 = PromptTemplate(
    input_variables = ['script'],
    template = plantilla3
)

cadena3 = prompt3 | modelo3

# %%
chainFin = (RunnablePassthrough()
    .assign(puntos = cadena1)
    .assign(script = cadena2)
    .assign(resultadoFinal = cadena3)
)

# %%
resultado = chainFin.invoke({"tema": 'Ingenieria de Datos'})

print("PUNTOS:\n", resultado["puntos"].content)
print("\nSCRIPT:\n", resultado["script"].content)
print("\nSEO FINAL:\n", resultado["resultadoFinal"].content)
# Out:
# PUNTOS:
#  1. Recolección de datos: La ingeniería de datos implica la recolección de datos de diversas fuentes, como bases de datos, archivos, sensores, redes sociales, etc.
#
# 2. Limpieza y procesamiento de datos: Es necesario limpiar y procesar los datos para eliminar errores, valores atípicos y redundancias, así como para estandarizar y normalizar los datos.
#
# 3. Integración de datos: La integración de datos consiste en combinar diferentes fuentes de datos para crear un único conjunto de datos coherente y completo.
#
# 4. Almacenamiento de datos: Los datos deben ser almacenados de manera eficiente y segura, utilizando tecnologías como bases de datos relacionales, bases de datos NoSQL, data lakes, entre otros.
#
# 5. Análisis de datos: Una vez que los datos están limpios, integrados y almacenados, se pueden realizar análisis para extraer información valiosa y tomar decisiones informadas.
#
# 6. Visualización de datos: La visualización de datos es importante para comunicar de manera efectiva los resultados del análisis a diferentes audiencias.
#
# 7. Seguridad de datos: Es fundamental garantizar la seguridad y privacidad de los datos, implementando medidas de seguridad como encriptación, control de acceso y auditorías.
#
# 8. Escalabilidad: La ingeniería de datos debe ser escalable para poder manejar grandes volúmenes de datos y crecer a medida que aumenta la cantidad de datos y la complejidad de los análisis.
#
# 9. Automatización: Es importante automatizar los procesos de recolección, limpieza, integración y análisis de datos para aumentar la eficiencia y reducir errores humanos.
#
# 10. Colaboración interdisciplinaria: La ingeniería de datos requiere la colaboración entre diferentes disciplinas, como la informática, las matemáticas, la estadística y el dominio del negocio, para garantizar que los datos se utilicen de manera efectiva para la toma de decisiones.
#
# SCRIPT:
#  Por supuesto, aquí tienes el guion completo para tu video acerca de la ingeniería de datos en YouTube:
#
# [Introducción]
# ¡Hola a todos! Hoy vamos a hablar sobre un tema fundamental en el mundo actual: la ingeniería de datos.
#
# [1. Recolección de datos]
# El proceso de la ingeniería de datos comienza con la recolección de datos de diversas fuentes, como bases de datos, archivos, sensores, redes sociales, entre otros. Es crucial recopilar la información necesaria para posteriormente analizarla y extraer conocimientos valiosos.
#
# [2. Limpieza y procesamiento de datos]
# Una vez que hemos recopilado los datos, es esencial limpiarlos y procesarlos. Esto implica eliminar errores, valores atípicos y redundancias, así como estandarizar y normalizar los datos para asegurar su calidad y fiabilidad.
#
# [3. Integración de datos]
# La integración de datos consiste en combinar diferentes fuentes de información para crear un único y coherente conjunto de datos. Esta etapa es fundamental para tener una visión completa de la información disponible.
#
# [4. Almacenamiento de datos]
# Los datos deben ser almacenados de manera eficiente y segura. Para ello, se utilizan tecnologías como bases de datos relacionales, bases de datos NoSQL y data lakes, entre otros, asegurando la disponibilidad y confidencialidad de la información.
#
# [5. Análisis de datos]
# Una vez que los datos han sido limpiados, integrados y almacenados, podemos realizar análisis para extraer información valiosa y tomar decisiones informadas. El análisis de datos nos permite obtener insights y descubrir patrones que de otra manera pasarían desapercibidos.
#
# [6. Visualización de datos]
# La visualización de datos es crucial para comunicar de manera efectiva los resultados del análisis a diferentes audiencias. Gráficos, tablas y dashboards son herramientas que nos ayudan a presentar la información de forma clara y comprensible.
#
# [7. Seguridad de datos]
# Garantizar la seguridad y privacidad de los datos es primordial en el proceso de ingeniería de datos. Medidas como la encriptación, el control de acceso y las auditorías son fundamentales para proteger la información de accesos no autorizados.
#
# [8. Escalabilidad]
# La ingeniería de datos debe ser escalable para poder manejar grandes volúmenes de información. A medida que la cantidad de datos y la complejidad de los análisis aumenta, es crucial contar con sistemas flexibles y escalables.
#
# [9. Automatización]
# Es importante automatizar los procesos de recolección, limpieza, integración y análisis de datos para aumentar la eficiencia y reducir errores humanos. La automatización nos permite optimizar el tiempo y los recursos dedicados al manejo de la información.
#
# [10. Colaboración interdisciplinaria]
# La ingeniería de datos requiere la colaboración entre diferentes disciplinas, como la informática, las matemáticas, la estadística y el dominio del negocio. Trabajar de forma interdisciplinaria nos permite aprovechar al máximo el potencial de los datos para la toma de decisiones.
#
# [Conclusión]
# En resumen, la ingeniería de datos es un proceso fundamental en la era digital en la que vivimos. Desde la recolección hasta la visualización de datos, cada etapa es importante para garantizar que la información sea aprovechada de manera efectiva. Espero que este video haya sido útil y te haya brindado una perspectiva más clara sobre la importancia de la ingeniería de datos en la actualidad.
#
# ¡Gracias por acompañarnos y nos vemos en el próximo video!
#
# SEO FINAL:
#  Título: ¿Cómo maximizar la eficiencia en el proceso de ingeniería de datos?
#
# Descripción:
# ¡Bienvenidos a un nuevo video, la guía definitiva sobre cómo maximizar la eficiencia en el proceso de ingeniería de datos! Encontrarás la descomposición detallada de todos los pasos esenciales en este intrigante proceso, resaltando la importancia de la recopilación de datos multicanal y como realizar limpieza y procesamiento efectivos en este episodio. El script te guiará paso a paso, desde explicaciones técnicas hasta ofrecer consejos prácticos para temas como la integración de datos y los procesos de almacenamiento. Explora todos los aspectos de la ingeniería de datos y ayúdate a caminar por derecho en tu viaje de manejo de datos. Independientemente de la complejidad y componente tecnológico, hemos procurado hacer que la explicación sea lo más clara y posible. El video aborda también tópicos como la visualización efectiva de datos, engranando el conocimiento que estos poseen, y los mecanismos de seguridad a tener en cuenta para proteger la información valiosa. Entendiendo que la ingeniería de datos evoluciona constantemente en términos de volumen y complejidad de información, se dan sugerencias para superar los desafíos de escalabilidad dentro de tu infraestructura de datos existente y cómo automatizar todo el proceso, garantizando la máxima eficiencia y reduciendo margenes de error. Aprecia la esencia de la colaboración interdisciplinaria en la ingeniería de datos y cómo el enfoque integrado puede ayudarte a desbloquear el verdadero valor de los datos. Sumérgete en la intersección de campos como informática, matemáticas, estadística y ámbitos empresariales. Resumiremos concisamente la importancia de la ingeniería de datos en este mundo digital y cómo navegar con destreza a través de cada paso. Notarás que, aunque es un tema avanzado, hemos hecho del aprendizaje un asunto sencillo de entender para ti. Esperamos que al final de este episodio sepas exactamente cómo aprovechar efectivamente la información y consigas obtener sus inmensos beneficios de negocio. Y recuerda, ¡estamos aquí para acompañarte en tu viaje de ingeniería de datos! ¡No te pierdas las futuras actualizaciones, nos vemos en el próximo video!

# %%
#Agentes LangChain

# %%
from langchain.agents import create_agent
from langchain_experimental.tools import PythonREPLTool
from langchain_openai import ChatOpenAI

# %%
modelo = ChatOpenAI(
    model = 'gpt-4o-mini',
    temperature=0)

# %%
print(modelo)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000001BC8D0E6BD0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001BC8D34FFE0> root_client=<openai.OpenAI object at 0x000001BC8D086480> root_async_client=<openai.AsyncOpenAI object at 0x000001BC8D0E6C60> model_name='gpt-4o-mini' temperature=0.0 model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
agenteEjecutor = create_agent(
    model = modelo,
    tools=[PythonREPLTool()]
)

# %%
agenteEjecutor.invoke(
    {'messages':[
        {'role':'user', 'content':'Cual es el resultado de pi elevado a la 5 solo sus primeros 10 decimales'}
    ]}
)
# Out:
# Python REPL can execute arbitrary code. Use with caution.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 agenteEjecutor.invoke(
#       2     {'messages':[
#       3         {'role':'user', 'content':'Cual es el resultado de pi elevado a la 5 solo sus primeros 10 decimales'}
#       4     ]}
#       5 )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\pregel\main.py:3071, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3068 chunks: list[dict[str, Any] | Any] = []
#    3069 interrupts: list[Interrupt] = []
# -> 3071 for chunk in self.stream(
#    3072     input,
#    3073     config,
#    3074     context=context,
#    3075     stream_mode=["updates", "values"]
#    3076     if stream_mode == "values"
#    3077     else stream_mode,
#    3078     print_mode=print_mode,
#    3079     output_keys=output_keys,
#    3080     interrupt_before=interrupt_before,
#    3081     interrupt_after=interrupt_after,
#    3082     durability=durability,
#    3083     **kwargs,
#    3084 ):
#    3085     if stream_mode == "values":
#    3086         if len(chunk) == 2:
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\pregel\main.py:2646, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2644 for task in loop.match_cached_writes():
#    2645     loop.output_writes(task.id, task.writes, cached=True)
# -> 2646 for _ in runner.tick(
#    2647     [t for t in loop.tasks.values() if not t.writes],
#    2648     timeout=self.step_timeout,
#    2649     get_waiter=get_waiter,
#    2650     schedule_task=loop.accept_push,
#    2651 ):
#    2652     # emit output
#    2653     yield from _output(
#    2654         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2655     )
#    2656 loop.after_tick()
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain\agents\factory.py:1261, in create_agent.<locals>.model_node(state, runtime)
#    1249 request = ModelRequest(
#    1250     model=model,
#    1251     tools=default_tools,
#    (...)   1257     runtime=runtime,
#    1258 )
#    1260 if wrap_model_call_handler is None:
# -> 1261     model_response = _execute_model_sync(request)
#    1262     return _build_commands(model_response)
#    1264 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain\agents\factory.py:1233, in create_agent.<locals>._execute_model_sync(request)
#    1230 if request.system_message:
#    1231     messages = [request.system_message, *messages]
# -> 1233 output = model_.invoke(messages)
#    1234 if name:
#    1235     output.name = name
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\runnables\base.py:5695, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5688 @override
#    5689 def invoke(
#    5690     self,
#    (...)   5693     **kwargs: Any | None,
#    5694 ) -> Output:
# -> 5695     return self.bound.invoke(
#    5696         input,
#    5697         self._merge_configs(config),
#    5698         **{**self.kwargs, **kwargs},
#    5699     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_openai\chat_models\base.py:1473, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1471     _handle_openai_bad_request(e)
#    1472 except openai.APIError as e:
# -> 1473     _handle_openai_api_error(e)
#    1474 except Exception as e:
#    1475     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_openai\chat_models\base.py:1468, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1461         return _construct_lc_result_from_responses_api(
#    1462             response,
#    1463             schema=original_schema_obj,
#    1464             metadata=generation_info,
#    1465             output_version=self.output_version,
#    1466         )
#    1467     else:
# -> 1468         raw_response = self.client.with_raw_response.create(**payload)
#    1469         response = raw_response.parse()
#    1470 except openai.BadRequestError as e:
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\resources\chat\completions\completions.py:1204, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1157 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1158 def create(
#    1159     self,
#    (...)   1201     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1202 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1203     validate_response_format(response_format)
# -> 1204     return self._post(
#    1205         "/chat/completions",
#    1206         body=maybe_transform(
#    1207             {
#    1208                 "messages": messages,
#    1209                 "model": model,
#    1210                 "audio": audio,
#    1211                 "frequency_penalty": frequency_penalty,
#    1212                 "function_call": function_call,
#    1213                 "functions": functions,
#    1214                 "logit_bias": logit_bias,
#    1215                 "logprobs": logprobs,
#    1216                 "max_completion_tokens": max_completion_tokens,
#    1217                 "max_tokens": max_tokens,
#    1218                 "metadata": metadata,
#    1219                 "modalities": modalities,
#    1220                 "n": n,
#    1221                 "parallel_tool_calls": parallel_tool_calls,
#    1222                 "prediction": prediction,
#    1223                 "presence_penalty": presence_penalty,
#    1224                 "prompt_cache_key": prompt_cache_key,
#    1225                 "prompt_cache_retention": prompt_cache_retention,
#    1226                 "reasoning_effort": reasoning_effort,
#    1227                 "response_format": response_format,
#    1228                 "safety_identifier": safety_identifier,
#    1229                 "seed": seed,
#    1230                 "service_tier": service_tier,
#    1231                 "stop": stop,
#    1232                 "store": store,
#    1233                 "stream": stream,
#    1234                 "stream_options": stream_options,
#    1235                 "temperature": temperature,
#    1236                 "tool_choice": tool_choice,
#    1237                 "tools": tools,
#    1238                 "top_logprobs": top_logprobs,
#    1239                 "top_p": top_p,
#    1240                 "user": user,
#    1241                 "verbosity": verbosity,
#    1242                 "web_search_options": web_search_options,
#    1243             },
#    1244             completion_create_params.CompletionCreateParamsStreaming
#    1245             if stream
#    1246             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1247         ),
#    1248         options=make_request_options(
#    1249             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1250         ),
#    1251         cast_to=ChatCompletion,
#    1252         stream=stream or False,
#    1253         stream_cls=Stream[ChatCompletionChunk],
#    1254     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-F5uhYsHFGHRIedWJEveAxIaJ on tokens per min (TPM): Limit 200000, Used 199380, Requested 844. Please try again in 67ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# During task with name 'model' and id '41bc1939-a011-2cd8-9a53-6ae04e315758'

# %% [markdown]
# #Indices en Pinecone

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override = True)
# Out:
# True

# %%
# %pip unistall pinecone-client -y
# %pip unistall pinecone -y
# %pip install pinecone
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "unistall" - maybe you meant "uninstall"
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "unistall" - maybe you meant "uninstall"
# Requirement already satisfied: pinecone in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (8.1.0)
# Requirement already satisfied: certifi>=2019.11.17 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone) (2026.1.4)
# Requirement already satisfied: orjson>=3.0.0 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone) (3.11.5)
# Requirement already satisfied: pinecone-plugin-assistant<4.0.0,>=3.0.1 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone) (3.0.2)
# Requirement already satisfied: pinecone-plugin-interface<0.1.0,>=0.0.7 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.5 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone) (2.6.3)
# Requirement already satisfied: packaging<25.0,>=24.2 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (24.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\od\onedrive - ti\documentos\sebastian carrero\programacion2026\entornospy\entornoprueba\lib\site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<4.0.0,>=3.0.1->pinecone) (3.11)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip list | findstr pinecone
# Out:
# pinecone                  8.1.0
# pinecone-client           6.0.0
# pinecone-plugin-assistant 3.0.2
# pinecone-plugin-interface 0.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from pinecone import Pinecone

load_dotenv()

api_key = os.getenv('PINECONE_API_KEY')

pc = Pinecone(api_key=api_key)
print(pc.list_indexes())
# Out:
# [{
#     "name": "langchan",
#     "metric": "cosine",
#     "host": "langchan-gfefbjz.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1536,
#     "deletion_protection": "disabled",
#     "tags": null
# }, {
#     "name": "primerindex",
#     "metric": "cosine",
#     "host": "primerindex-gfefbjz.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "region": "us-east-1",
#             "cloud": "aws",
#             "read_capacity": {
#                 "mode": "OnDemand",
#                 "status": {
#                     "state": "Ready",
#                     "current_shards": null,
#                     "current_replicas": null
#                 }
#             }
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1024,
#     "deletion_protection": "disabled",
#     "tags": null,
#     "embed": {
#         "model": "llama-text-embed-v2",
#         "field_map": {
#             "text": "text"
#         },
#         "dimension": 1024,
#         "metric": "cosine",
#         "write_parameters": {
#             "dimension": 1024,
#             "input_type": "passage",
#             "truncate": "END"
#         },
#         "read_parameters": {
#             "dimension": 1024,
#             "input_type": "query",
#             "truncate": "END"
#         },
#         "vector_type": "dense"
#     }
# }]

# %%
pc.list_indexes()
# Out:
# [
#     {
#         "name": "langchan",
#         "metric": "cosine",
#         "host": "langchan-gfefbjz.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1536,
#         "deletion_protection": "disabled",
#         "tags": null
#     },
#     {
#         "name": "primerindex",
#         "metric": "cosine",
#         "host": "primerindex-gfefbjz.svc.aped-4627-b74a.pinecone.io",
#         "spec": {
#             "serverless": {
#                 "region": "us-east-1",
#                 "cloud": "aws",
#                 "read_capacity": {
#                     "mode": "OnDemand",
#                     "status": {
#                         "state": "Ready",
#                         "current_shards": null,
#                         "current_replicas": null
#                     }
#                 }
#             }
#         },
#         "status": {
#             "ready": true,
#             "state": "Ready"
#         },
#         "vector_type": "dense",
#         "dimension": 1024,
#         "deletion_protection": "disabled",
#         "tags": null,
#         "embed": {
#             "model": "llama-text-embed-v2",
#             "field_map": {
#                 "text": "text"
#             },
#             "dimension": 1024,
#             "metric": "cosine",
#             "write_parameters": {
#                 "dimension": 1024,
#                 "input_type": "passage",
#                 "truncate": "END"
#             },
#             "read_parameters": {
#                 "dimension": 1024,
#                 "input_type": "query",
#                 "truncate": "END"
#             },
#             "vector_type": "dense"
#         }
#     }
# ]

# %%
indice = 'langchan'

# %%
pc.create_index(indice, dimension=1536, metric='cosine',
                spec={
                    'serverless':{
                        'cloud':'aws',
                        'region':'us-east-1'
                    }
                })
# Out:
# ---------------------------------------------------------------------------
# PineconeApiException                      Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 pc.create_index(indice, dimension=1536, metric='cosine',
#       2                 spec={
#       3                     'serverless':{
#       4                         'cloud':'aws',
#       5                         'region':'us-east-1'
#       6                     }
#       7                 })
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\pinecone.py:499, in Pinecone.create_index(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#     378 def create_index(
#     379     self,
#     380     name: str,
#    (...)    387     tags: dict[str, str] | None = None,
#     388 ) -> "IndexModel":
#     389     """Creates a Pinecone index.
#     390
#     391     :param name: The name of the index to create. Must be unique within your project and
#    (...)    497
#     498     """
# --> 499     return self.db.index.create(
#     500         name=name,
#     501         spec=spec,
#     502         dimension=dimension,
#     503         metric=metric,
#     504         timeout=timeout,
#     505         deletion_protection=deletion_protection,
#     506         vector_type=vector_type,
#     507         tags=tags,
#     508     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\utils\require_kwargs.py:26, in require_kwargs.<locals>.wrapper(*args, **kwargs)
#      21     param_names = list(inspect.signature(func).parameters.keys())[1:]  # Skip self
#      22     raise TypeError(
#      23         f"{func.__name__}() requires keyword arguments. "
#      24         f"Please use {func.__name__}({', '.join(f'{name}=value' for name in param_names)})"
#      25     )
# ---> 26 return func(*args, **kwargs)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\db_control\resources\sync\index.py:95, in IndexResource.create(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#      73 @require_kwargs
#      74 def create(
#      75     self,
#    (...)     84     tags: dict[str, str] | None = None,
#      85 ) -> IndexModel:
#      86     req = PineconeDBControlRequestFactory.create_index_request(
#      87         name=name,
#      88         spec=spec,
#    (...)     93         tags=tags,
#      94     )
# ---> 95     resp = self._index_api.create_index(create_index_request=req)
#      97     if timeout == -1:
#      98         from typing import cast
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\core\openapi\db_control\api\manage_indexes_api.py:375, in ManageIndexesApi.__init__.<locals>.__create_index(self, create_index_request, x_pinecone_api_version, **kwargs)
#     373 kwargs["x_pinecone_api_version"] = x_pinecone_api_version
#     374 kwargs["create_index_request"] = create_index_request
# --> 375 return cast(IndexModel | ApplyResult[IndexModel], self.call_with_http_info(**kwargs))
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\api_client.py:320, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     299     return self.threadpool_executor.submit(
#     300         self.__call_api,
#     301         resource_path,
#    (...)    316         _check_type,
#     317     )
#     319 if not async_req:
# --> 320     return self.__call_api(
#     321         resource_path,
#     322         method,
#     323         path_params,
#     324         query_params,
#     325         header_params,
#     326         body,
#     327         post_params,
#     328         files,
#     329         response_type,
#     330         auth_settings,
#     331         _return_http_data_only,
#     332         collection_formats,
#     333         _preload_content,
#     334         _request_timeout,
#     335         _host,
#     336         _check_type,
#     337     )
#     339 return self.pool.apply_async(
#     340     self.__call_api,
#     341     (
#    (...)    358     ),
#     359 )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\api_client.py:185, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     183 except PineconeApiException as e:
#     184     e.body = e.body.decode("utf-8")
# --> 185     raise e
#     187 self.last_response = response_data
#     189 return_data = response_data
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\api_client.py:173, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     164 url = build_request_url(
#     165     config=config,
#     166     processed_path_params=path_params_tuple,
#     167     resource_path=resource_path,
#     168     _host=_host,
#     169 )
#     171 try:
#     172     # perform request and return response
# --> 173     response_data = self.request(
#     174         method,
#     175         url,
#     176         query_params=processed_query_params,
#     177         headers=headers_tuple,
#     178         post_params=processed_post_params,
#     179         body=body,
#     180         _preload_content=_preload_content,
#     181         _request_timeout=_request_timeout,
#     182     )
#     183 except PineconeApiException as e:
#     184     e.body = e.body.decode("utf-8")
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\api_client.py:400, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     390     return self.rest_client.OPTIONS(
#     391         url,
#     392         query_params=query_params,
#    (...)    397         body=body,
#     398     )
#     399 elif method == "POST":
# --> 400     return self.rest_client.POST(
#     401         url,
#     402         query_params=query_params,
#     403         headers=headers,
#     404         post_params=post_params,
#     405         _preload_content=_preload_content,
#     406         _request_timeout=_request_timeout,
#     407         body=body,
#     408     )
#     409 elif method == "PUT":
#     410     return self.rest_client.PUT(
#     411         url,
#     412         query_params=query_params,
#    (...)    417         body=body,
#     418     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\rest_utils.py:146, in RestClientInterface.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     136 def POST(
#     137     self,
#     138     url,
#    (...)    144     _request_timeout=None,
#     145 ):
# --> 146     return self.request(
#     147         "POST",
#     148         url,
#     149         headers=headers,
#     150         query_params=query_params,
#     151         post_params=post_params,
#     152         _preload_content=_preload_content,
#     153         _request_timeout=_request_timeout,
#     154         body=body,
#     155     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\rest_urllib3.py:270, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     267     # log response body
#     268     logger.debug("response body: %s", r.data)
# --> 270 return raise_exceptions_or_return(r)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\pinecone\openapi_support\rest_utils.py:49, in raise_exceptions_or_return(r)
#      46     if 500 <= r.status <= 599:
#      47         raise ServiceException(http_resp=r)
# ---> 49     raise PineconeApiException(http_resp=r)
#      51 return r
#
# PineconeApiException: (409)
# Reason: Conflict
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'vary': 'origin, access-control-request-method, access-control-request-headers', 'access-control-allow-origin': '*', 'access-control-expose-headers': '*', 'x-pinecone-api-version': '2025-10', 'x-cloud-trace-context': '4d2afa0ac002c0ac31065725b07d5ac4', 'date': 'Mon, 09 Mar 2026 15:11:50 GMT', 'server': 'Google Frontend', 'Content-Length': '85', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"ALREADY_EXISTS","message":"Resource  already exists"},"status":409}

# %%
index = pc.Index(indice)

# %%
index.describe_index_stats()
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '151',
#                                     'content-type': 'application/json',
#                                     'date': 'Mon, 09 Mar 2026 15:12:29 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '42',
#                                     'x-pinecone-request-latency-ms': '41',
#                                     'x-pinecone-response-duration-ms': '43'}},
#  'dimension': 1536,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'storageFullness': 0.0,
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %% [markdown]
# ##Crear y agregar vectores a Pinecone

# %%
index.describe_index_stats()
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '151',
#                                     'content-type': 'application/json',
#                                     'date': 'Mon, 09 Mar 2026 15:12:29 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '38',
#                                     'x-pinecone-request-latency-ms': '38',
#                                     'x-pinecone-response-duration-ms': '40'}},
#  'dimension': 1536,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'storageFullness': 0.0,
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %%
import random
vectores = [[random.random() for i in range(1536)] for mv in range(10)]

# %%
vectores[3]
# Out:
# [0.15524143503401244,
#  0.44051720452611676,
#  0.3063777989344695,
#  0.4428679492131362,
#  0.4348481032742917,
#  0.4924895352175582,
#  0.46423936692315404,
#  0.6300650458632536,
#  0.5184705441812892,
#  0.20758783700980732,
#  0.9922976950243091,
#  0.6505148576988345,
#  0.5420094855237911,
#  0.9089026995618458,
#  0.1391467234734527,
#  0.827492415916547,
#  0.7112275033128586,
#  0.9222365054507515,
#  0.5364075511645277,
#  0.6403332670218093,
#  0.10160115545889137,
#  0.0936126604525499,
#  0.20071736947762842,
#  0.8244476707661738,
#  0.043247474669976915,
#  0.9329439308559577,
#  0.36029285802495226,
#  0.45890972288532994,
#  0.4782264930378486,
#  0.228210008098519,
#  0.4016368299025995,
#  0.04723514106677451,
#  0.947846630276509,
#  0.27341296249239677,
#  0.22800322083572377,
#  0.5661167056185749,
#  0.8708966748559813,
#  0.7139739578417754,
#  0.5757406385669402,
#  0.18593305989237818,
#  0.09644411773429684,
#  0.5435664948746076,
#  0.061190704766150295,
#  0.6453831394487072,
#  0.948663966785156,
#  0.14067189035018945,
#  0.6113209448281953,
#  0.3483711547299261,
#  0.8890039475178477,
#  0.5638623665884295,
#  0.6602808405190695,
#  0.6617140092331772,
#  0.30322294702326025,
#  0.4883558324447034,
#  0.2344403911252947,
#  0.4917448054088013,
#  0.8339929293049977,
#  0.5129496349201678,
#  0.23886217178930103,
#  0.36897381747411007,
#  0.14926481225298127,
#  0.4853010492665675,
#  0.5268644396773727,
#  0.7477715234260683,
#  0.9095538990710947,
#  0.4847602858853747,
#  0.6168431541735515,
#  0.43329739106924015,
#  0.4606985540523556,
#  0.7589528357399024,
#  0.5006973438781531,
#  0.7978925451047836,
#  0.030877775801731122,
#  0.910397185988525,
#  0.946438953176739,
#  0.3086984223154877,
#  0.688710466743316,
#  0.5817552704263723,
#  0.8188514044849527,
#  0.11910452158839469,
#  0.14580785554977693,
#  0.7322900363119077,
#  0.047579941711740514,
#  0.08449548551133812,
#  0.9466341042592319,
#  0.35705556731204946,
#  0.9655209930394657,
#  0.8004877619252281,
#  0.7294049126424863,
#  0.6263426940814275,
#  0.4173055311487023,
#  0.4513276939663168,
#  0.9228833476148783,
#  0.11018576306259686,
#  0.6194245022340004,
#  0.5435930885258493,
#  0.22976441570977535,
#  0.37884222707847237,
#  0.6280631031114713,
#  0.815356810484337,
#  0.01301694628196437,
#  0.6497901935009063,
#  0.5654580809623839,
#  0.7545239156896757,
#  0.5638972327519204,
#  0.7329933517691394,
#  0.03431069457751923,
#  ...]

# %%
# vectores id
ids = list('abcdefghij')
ids
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
index_name = 'langchan'
print(index_name)
# Out:
# langchan

# %%
index = pc.Index(index_name)

# %%
index.describe_index_stats()
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '151',
#                                     'content-type': 'application/json',
#                                     'date': 'Mon, 09 Mar 2026 15:17:09 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '58',
#                                     'x-pinecone-request-latency-ms': '58',
#                                     'x-pinecone-response-duration-ms': '60'}},
#  'dimension': 1536,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {},
#  'storageFullness': 0.0,
#  'total_vector_count': 0,
#  'vector_type': 'dense'}

# %%
index.upsert(vectors=zip(ids, vectores))
# Out:
# UpsertResponse(upserted_count=10, _response_info={'raw_headers': {'date': 'Mon, 09 Mar 2026 15:17:10 GMT', 'content-type': 'application/json', 'content-length': '20', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '1', 'x-pinecone-request-logical-size': '61450', 'x-pinecone-request-latency-ms': '991', 'x-envoy-upstream-service-time': '303', 'x-pinecone-response-duration-ms': '993', 'grpc-status': '0', 'server': 'envoy'}})

# %% [markdown]
# #Mostrar un vector

# %%
index.fetch(ids=['h'])
# Out:
# FetchResponse(namespace='', vectors={'h': Vector(id='h', values=[0.972618461, 0.359531015, 0.599682152, 0.317603022, 0.460962564, 0.567939639, 0.257488757, 0.384923726, 0.659440219, 0.281055421, 0.387194395, 0.749046504, 0.327753037, 0.811373, 0.352076411, 0.921437621, 0.923619092, 0.332828283, 0.254815936, 0.861274302, 0.694483101, 0.570822, 0.522876382, 0.727740824, 0.634254932, 0.806258917, 0.252378136, 0.928638, 0.756334066, 0.147186026, 0.28384006, 0.016794635, 0.0345912427, 0.302086055, 0.429201394, 0.548164, 0.634277761, 0.0090701757, 0.253923863, 0.921209872, 0.14263396, 0.212557897, 0.413131535, 0.754701138, 0.411041379, 0.164127588, 0.484877825, 0.668581188, 0.393550098, 0.703311861, 0.957961142, 0.912026286, 0.263232261, 0.327213794, 0.136953413, 0.327009261, 0.0737083629, 0.671863854, 0.656018555, 0.700523317, 0.185124621, 0.423141122, 0.417363912, 0.575560689, 0.750101864, 0.00887125824, 0.904607534, 0.645747781, 0.321665, 0.456108, 0.157529429, 0.371520281, 0.219223127, 0.540153384, 0.508036137, 0.972654641, 0.977311254, 0.301196605, 0.945014, 0.935361
# %% [markdown]
# #Actualizar un vector

# %%
index.upsert(vectors=[('h',[0.754] * 1536)])
# Out:
# UpsertResponse(upserted_count=1, _response_info={'raw_headers': {'date': 'Mon, 09 Mar 2026 15:30:11 GMT', 'content-type': 'application/json', 'content-length': '19', 'connection': 'keep-alive', 'x-pinecone-request-lsn': '2', 'x-pinecone-request-logical-size': '6145', 'x-pinecone-request-latency-ms': '252', 'x-envoy-upstream-service-time': '167', 'x-pinecone-response-duration-ms': '254', 'grpc-status': '0', 'server': 'envoy'}})

# %%
index.fetch(ids=['h'])
# Out:
# FetchResponse(namespace='', vectors={'h': Vector(id='h', values=[0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0.754, 0 ...

# %% [markdown]
# #Borrar un vector

# %%
index.delete(ids=['h'])
# Out:
# {'_response_info': {'raw_headers': {'date': 'Mon, 09 Mar 2026 15:31:56 GMT',
#    'content-type': 'application/json',
#    'content-length': '2',
#    'connection': 'keep-alive',
#    'x-pinecone-request-lsn': '3',
#    'x-pinecone-request-logical-size': '0',
#    'x-pinecone-request-latency-ms': '161',
#    'x-envoy-upstream-service-time': '162',
#    'x-pinecone-response-duration-ms': '163',
#    'grpc-status': '0',
#    'server': 'envoy'}}}

# %%
index.describe_index_stats()
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '182',
#                                     'content-type': 'application/json',
#                                     'date': 'Mon, 09 Mar 2026 15:32:33 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '47',
#                                     'x-pinecone-request-latency-ms': '46',
#                                     'x-pinecone-response-duration-ms': '48'}},
#  'dimension': 1536,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'__default__': {'vector_count': 9}},
#  'storageFullness': 0.0,
#  'total_vector_count': 9,
#  'vector_type': 'dense'}

# %%
index.fetch(ids=['h'])
# Out:
# FetchResponse(namespace='', vectors={}, usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Mon, 09 Mar 2026 15:33:09 GMT', 'content-type': 'application/json', 'content-length': '53', 'connection': 'keep-alive', 'x-pinecone-request-latency-ms': '42', 'x-envoy-upstream-service-time': '43', 'x-pinecone-response-duration-ms': '44', 'grpc-status': '0', 'server': 'envoy'}})

# %% [markdown]
# #Consultas

# %%
vector2 = [[random.random() for _ in range(1536)]]
vector2
# Out:
# [[0.8712844499229104,
#   0.15522076567162935,
#   0.48136779471072466,
#   0.4083372997460496,
#   0.4799174322596039,
#   0.08663351173957823,
#   0.342988846587704,
#   0.49634591652932825,
#   0.9382419363010762,
#   0.4902667781798914,
#   0.2425178668444251,
#   0.5613901013090006,
#   0.030484774019216676,
#   0.35865098926778505,
#   0.08261301727619419,
#   0.2808743939291306,
#   0.013835300061189493,
#   0.0907342760626948,
#   0.7843463292226688,
#   0.30734920294224244,
#   0.22968952420358746,
#   0.3477906506001589,
#   0.7626389180554215,
#   0.7489415559461227,
#   0.8888781903553348,
#   0.31679323728440234,
#   0.6215963383383806,
#   0.9652332092463668,
#   0.5118510471089549,
#   0.24315143463109,
#   0.436059458956393,
#   0.5637178868681729,
#   0.26701798370279917,
#   0.9878316750434146,
#   0.6247662192349397,
#   0.5002204775601037,
#   0.5162008335160292,
#   0.823951600963673,
#   0.7766716883450606,
#   0.832255858051245,
#   0.8033953242591273,
#   0.3474951818058182,
#   0.30076594420254354,
#   0.2830396311407787,
#   0.4440566780946441,
#   0.4847180343887413,
#   0.20576200506037734,
#   0.9861658212515145,
#   0.5407479246263768,
#   0.8062533106985574,
#   0.4335262200853476,
#   0.8482851201056594,
#   0.3155827549493402,
#   0.12925587824178675,
#   0.9687501983583034,
#   0.44808106626852784,
#   0.9704064546952743,
#   0.8066547770660467,
#   0.3287519015491055,
#   0.9451640028273581,
#   0.6837592556449256,
#   0.017543235229654952,
#   0.2946060805409165,
#   0.38081002071940084,
#   0.3575493944643079,
#   0.4774339406438046,
#   0.5634688655376325,
#   0.8838789851373404,
#   0.14476783425418416,
#   0.8184822617283881,
#   0.9408952099204596,
#   0.9379109999703413,
#   0.7589807081289541,
#   0.6180957611232281,
#   0.40621466506119963,
#   0.4813809544268274,
#   0.6529695328276433,
#   0.2940737880428188,
#   0.3675847881046571,
#   0.5584145223047208,
#   0.9333939300824097,
#   0.9082563573124869,
#   0.0027423875152619015,
#   0.7649974627011212,
#   0.47965607617713857,
#   0.4537620189710184,
#   0.18962599867587449,
#   0.8355586097984414,
#   0.8596248689151984,
#   0.3976636967265217,
#   0.268925535388859,
#   0.46189523949651157,
#   0.43681902075597745,
#   0.4556447345493543,
#   0.6511926880052002,
#   0.3164943600901322,
#   0.07440822826442661,
#   0.9631850094012339,
#   0.8283476995703397,
#   0.3963012893385963,
#   0.9484999666225603,
#   0.34870198881863834,
#   0.20334384239967618,
#   0.16651664086254703,
#   0.7549926025767363,
#   0.06687461126452277,
#   0.1488763066975214,
#   0.3561309898834486,
#   ...]]

# %%
index.query(
    vector=vector2,
    top_k = 9,
    include_values= False
)
# Out:
# QueryResponse(matches=[{'id': 'd', 'score': 0.767631114, 'values': []}, {'id': 'b', 'score': 0.760038912, 'values': []}, {'id': 'f', 'score': 0.757470965, 'values': []}, {'id': 'c', 'score': 0.757236481, 'values': []}, {'id': 'a', 'score': 0.752540469, 'values': []}, {'id': 'g', 'score': 0.751150846, 'values': []}, {'id': 'j', 'score': 0.750182092, 'values': []}, {'id': 'i', 'score': 0.747918546, 'values': []}, {'id': 'e', 'score': 0.746837735, 'values': []}], namespace='', usage={'read_units': 1}, _response_info={'raw_headers': {'date': 'Mon, 09 Mar 2026 15:42:18 GMT', 'content-type': 'application/json', 'content-length': '452', 'connection': 'keep-alive', 'x-pinecone-max-indexed-lsn': '3', 'x-pinecone-request-latency-ms': '176', 'x-envoy-upstream-service-time': '4', 'x-pinecone-response-duration-ms': '178', 'grpc-status': '0', 'server': 'envoy'}})
