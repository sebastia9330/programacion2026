# %% [markdown]
# #Instalar librerias

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.2.10
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.10

# %% [markdown]
# ##Configurar el dotenv

# %%
import os 
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv('./KEY.env')#buscar con nombre
# Out:
# False

# %%
load_dotenv(find_dotenv(), override= True)# buscar sin nombre
# Out:
# True

# %%
os.environ.get('OPEN_API_KEY')

# %% [markdown]
# LLM NODELS (GPT3.5)

# %%
from langchain_openai import OpenAI

# %%
gpt3 = OpenAI(model_name='gpt-3.5-turbo-instruct', temperature=0.7, max_tokens=1024)

# %%
print(gpt3)
# Out:
# OpenAI
# Params: {'model_name': 'gpt-3.5-turbo-instruct', 'temperature': 0.7, 'top_p': 1, 'frequency_penalty': 0, 'presence_penalty': 0, 'n': 1, 'seed': None, 'logprobs': None, 'max_tokens': 1024}

# %%
respuesta = gpt3.invoke("Explica qué es un modelo de IA LLM")

# %%
print(respuesta)
# Out:
# Un modelo de IA LLM (por sus siglas en inglés, Language Model) es un sistema de inteligencia artificial diseñado para procesar y comprender el lenguaje humano. Este tipo de modelo es entrenado a partir de grandes cantidades de datos de texto para aprender patrones y estructuras del lenguaje, lo que le permite generar texto coherente y relevante en respuesta a una entrada dada.
#
# El objetivo principal de un modelo de IA LLM es mejorar la capacidad de una máquina para entender y producir lenguaje natural, lo que lo hace útil en una amplia gama de aplicaciones, como asistentes virtuales, traducción automática, análisis de sentimientos y generación de contenido.
#
# Para entrenar un modelo de IA LLM, se utilizan técnicas de aprendizaje profundo y algoritmos de procesamiento de lenguaje natural. Estos modelos pueden ser entrenados en diferentes idiomas y dominios, lo que les permite adaptarse a diferentes tareas y contextos.
#
# Algunos ejemplos de modelos de IA LLM ampliamente conocidos son GPT-3 (Generative Pre-trained Transformer), BERT (Bidirectional Encoder Representations from Transformers) y ELMO (Embeddings from Language Models). Estos modelos han demostrado un gran avance en la comprensión y generación de lenguaje natural, y son utilizados por empresas y organizaciones en diversas aplicaciones de IA.

# %%
respuestas = gpt3.generate(['Cual es la capital de colombia',
                            'que es oracle',
                            'se puede conectar un llm a oracle'])

# %%
print(respuestas)
# Out:
# generations=[[Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nOracle es una empresa de tecnología especializada en soluciones de gestión de bases de datos y aplicaciones empresariales. Fundada en 1977, Oracle es una de las empresas líderes en el mercado de software empresarial y ofrece una amplia gama de productos y servicios, incluyendo bases de datos, aplicaciones de negocio, middleware, hardware y servicios en la nube. La plataforma de bases de datos de Oracle es una de las más populares y utilizadas en la industria, y sus aplicaciones empresariales son utilizadas por miles de empresas en todo el mundo para gestionar sus operaciones y procesos comerciales. Oracle también es conocida por su enfoque en la innovación tecnológica y su compromiso con la seguridad y confiabilidad de sus productos y servicios.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nSí, se puede conectar un software LLM (License Lifecycle Manager) a una base de datos Oracle. Para ello, es necesario contar con un controlador JDBC de Oracle que permita la conexión entre ambas aplicaciones. Una vez instalado el controlador, se pueden seguir los pasos específicos del LLM para establecer la conexión con la base de datos Oracle y comenzar a gestionar las licencias de software de manera eficiente.', generation_info={'finish_reason': 'stop', 'logprobs': None})]] llm_output={'token_usage': {'prompt_tokens': 19, 'total_tokens': 292, 'completion_tokens': 273}, 'model_name': 'gpt-3.5-turbo-instruct'} run=[RunInfo(run_id=UUID('019c905e-8ac9-7f80-873d-4f28c800e224')), RunInfo(run_id=UUID('019c905e-8ac9-7f80-873d-4f3492c02bfa')), RunInfo(run_id=UUID('019c905e-8ac9-7f80-873d-4f430279c24f'))] type='LLMResult'

# %%
print(respuestas.generations)
# Out:
# [[Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nOracle es una empresa de tecnología especializada en soluciones de gestión de bases de datos y aplicaciones empresariales. Fundada en 1977, Oracle es una de las empresas líderes en el mercado de software empresarial y ofrece una amplia gama de productos y servicios, incluyendo bases de datos, aplicaciones de negocio, middleware, hardware y servicios en la nube. La plataforma de bases de datos de Oracle es una de las más populares y utilizadas en la industria, y sus aplicaciones empresariales son utilizadas por miles de empresas en todo el mundo para gestionar sus operaciones y procesos comerciales. Oracle también es conocida por su enfoque en la innovación tecnológica y su compromiso con la seguridad y confiabilidad de sus productos y servicios.', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nSí, se puede conectar un software LLM (License Lifecycle Manager) a una base de datos Oracle. Para ello, es necesario contar con un controlador JDBC de Oracle que permita la conexión entre ambas aplicaciones. Una vez instalado el controlador, se pueden seguir los pasos específicos del LLM para establecer la conexión con la base de datos Oracle y comenzar a gestionar las licencias de software de manera eficiente.', generation_info={'finish_reason': 'stop', 'logprobs': None})]]

# %%
print(respuestas.generations[0])
# Out:
# [Generation(text='\n\nLa capital de Colombia es Bogotá.', generation_info={'finish_reason': 'stop', 'logprobs': None})]

# %%
print(respuestas.generations[0][0])
# Out:
# text='\n\nLa capital de Colombia es Bogotá.' generation_info={'finish_reason': 'stop', 'logprobs': None}

# %%
print(respuestas.generations[0][0].text)
# Out:
# La capital de Colombia es Bogotá.

# %%
print(respuestas.generations[1][0].text)
# Out:
# Oracle es una empresa de tecnología especializada en soluciones de gestión de bases de datos y aplicaciones empresariales. Fundada en 1977, Oracle es una de las empresas líderes en el mercado de software empresarial y ofrece una amplia gama de productos y servicios, incluyendo bases de datos, aplicaciones de negocio, middleware, hardware y servicios en la nube. La plataforma de bases de datos de Oracle es una de las más populares y utilizadas en la industria, y sus aplicaciones empresariales son utilizadas por miles de empresas en todo el mundo para gestionar sus operaciones y procesos comerciales. Oracle también es conocida por su enfoque en la innovación tecnológica y su compromiso con la seguridad y confiabilidad de sus productos y servicios.

# %%
print(respuestas.generations[2][0].text)
# Out:
# Sí, se puede conectar un software LLM (License Lifecycle Manager) a una base de datos Oracle. Para ello, es necesario contar con un controlador JDBC de Oracle que permita la conexión entre ambas aplicaciones. Una vez instalado el controlador, se pueden seguir los pasos específicos del LLM para establecer la conexión con la base de datos Oracle y comenzar a gestionar las licencias de software de manera eficiente.

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

# %%
chat = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.5, max_tokens=1024)

# %%
mensajes = [
    SystemMessage(content = 'Eres un experto en ingenieria de datos y quieres ser mi maestro'),
    HumanMessage(content = 'Escribe los pasos mas importantes para ser el mejor ingeniero de datos del mundo y ser un referente en la materia')
]
respuesta = chat.invoke(mensajes)

# %%
respuesta
# Out:
# AIMessage(content='Para convertirte en un experto en ingeniería de datos y ser un referente en la materia, aquí te dejo algunos pasos importantes a seguir:\n\n1. **Formación académica sólida**: Es importante contar con una base sólida en matemáticas, estadística, ciencias de la computación y programación. Considera obtener un título universitario en informática, ingeniería de software, ciencias de la computación o una disciplina relacionada.\n\n2. **Especialización en ingeniería de datos**: Realiza cursos o programas de formación específicos en ingeniería de datos. Aprende sobre bases de datos, procesamiento de datos, lenguajes de programación como Python y herramientas como Hadoop, Spark, SQL, entre otros.\n\n3. **Experiencia práctica**: Aplica tus conocimientos en proyectos reales. Trabaja en proyectos de datos dentro de tu empresa, participa en competencias de ciencia de datos o realiza proyectos por tu cuenta para ganar experiencia práctica.\n\n4. **Mantente actualizado**: La tecnología en el campo de la ingeniería de datos avanza rápidamente. Mantente al día con las últimas tendencias, herramientas y técnicas en el campo. Participa en conferencias, seminarios, webinars y lee blogs y libros especializados.\n\n5. **Desarrolla habilidades de comunicación**: La ingeniería de datos no se trata solo de trabajar con datos, sino también de comunicar de manera efectiva tus hallazgos y resultados a diferentes audiencias. Mejora tus habilidades de comunicación verbal y escrita.\n\n6. **Trabaja en equipo**: La colaboración es clave en la ingeniería de datos. Aprende a trabajar en equipo, a compartir conocimientos y a colaborar con otros profesionales, como científicos de datos, analistas y desarrolladores.\n\n7. **Cultiva la curiosidad y la resolución de problemas**: La curiosidad y la capacidad para resolver problemas son cualidades fundamentales en la ingeniería de datos. Siempre mantente curioso, busca nuevas formas de abordar desafíos y no tengas miedo de enfrentarte a problemas complejos.\n\n8. **Mantén altos estándares éticos**: Trabajar con datos implica una gran responsabilidad ética. Asegúrate de mantener altos estándares éticos en tu trabajo, protegiendo la privacidad y la seguridad de los datos y siguiendo las regulaciones y normativas vigentes.\n\nSiguiendo estos pasos y manteniendo una actitud de aprendizaje continuo, podrás convertirte en un experto en ingeniería de datos y ser un referente en la materia. ¡Buena suerte en tu camino hacia la excelencia en este campo!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 610, 'prompt_tokens': 53, 'total_tokens': 663, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DCp4yLxwGxhfdSfW7kVunj6QJJaVi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c905e-c663-7292-ab86-bb778fb4d067-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 610, 'total_tokens': 663, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
respuesta.content
# Out:
# 'Para convertirte en un experto en ingeniería de datos y ser un referente en la materia, aquí te dejo algunos pasos importantes a seguir:\n\n1. **Formación académica sólida**: Es importante contar con una base sólida en matemáticas, estadística, ciencias de la computación y programación. Considera obtener un título universitario en informática, ingeniería de software, ciencias de la computación o una disciplina relacionada.\n\n2. **Especialización en ingeniería de datos**: Realiza cursos o programas de formación específicos en ingeniería de datos. Aprende sobre bases de datos, procesamiento de datos, lenguajes de programación como Python y herramientas como Hadoop, Spark, SQL, entre otros.\n\n3. **Experiencia práctica**: Aplica tus conocimientos en proyectos reales. Trabaja en proyectos de datos dentro de tu empresa, participa en competencias de ciencia de datos o realiza proyectos por tu cuenta para ganar experiencia práctica.\n\n4. **Mantente actualizado**: La tecnología en el campo de la ingeniería de datos avanza rápidamente. Mantente al día con las últimas tendencias, herramientas y técnicas en el campo. Participa en conferencias, seminarios, webinars y lee blogs y libros especializados.\n\n5. **Desarrolla habilidades de comunicación**: La ingeniería de datos no se trata solo de trabajar con datos, sino también de comunicar de manera efectiva tus hallazgos y resultados a diferentes audiencias. Mejora tus habilidades de comunicación verbal y escrita.\n\n6. **Trabaja en equipo**: La colaboración es clave en la ingeniería de datos. Aprende a trabajar en equipo, a compartir conocimientos y a colaborar con otros profesionales, como científicos de datos, analistas y desarrolladores.\n\n7. **Cultiva la curiosidad y la resolución de problemas**: La curiosidad y la capacidad para resolver problemas son cualidades fundamentales en la ingeniería de datos. Siempre mantente curioso, busca nuevas formas de abordar desafíos y no tengas miedo de enfrentarte a problemas complejos.\n\n8. **Mantén altos estándares éticos**: Trabajar con datos implica una gran responsabilidad ética. Asegúrate de mantener altos estándares éticos en tu trabajo, protegiendo la privacidad y la seguridad de los datos y siguiendo las regulaciones y normativas vigentes.\n\nSiguiendo estos pasos y manteniendo una actitud de aprendizaje continuo, podrás convertirte en un experto en ingeniería de datos y ser un referente en la materia. ¡Buena suerte en tu camino hacia la excelencia en este campo!'

# %% [markdown]
# ##Prompt Templates

# %%
from langchain_core.prompts import PromptTemplate

# %%
#Creacion de una plantilla de prompt
plantilla = """
    Escribe un mensaje de felicitacion para {nombre} en su {ocasion}
"""

# %%
prompt = PromptTemplate(
    input_variables=['nombre', 'ocasion'],
    template=plantilla
)

# %%
print(prompt)
# Out:
# input_variables=['nombre', 'ocasion'] input_types={} partial_variables={} template='\n    Escribe un mensaje de felicitacion para {nombre} en su {ocasion}\n'

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.5, max_tokens=1024)
respuesta = llm.invoke(prompt.format(nombre='Sebastian', ocasion='Tristeza'))
print(respuesta.content)
# Out:
# Querido Sebastian, sé que estás pasando por un momento difícil y lleno de tristeza, pero quiero recordarte que eres una persona fuerte y valiente. No estás solo en esto, cuentas con el apoyo y el cariño de quienes te rodean. Confía en que pronto encontrarás la luz en medio de la oscuridad y que esta tristeza pasará. ¡Ánimo y fuerza, querido amigo! Estoy aquí para ti en todo momento.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough

# %%
modelo1 = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=0.7, max_tokens=1024)
plantilla = """
    Escriba los puntos mas importantes para {tema}
"""

# %%
prompt = PromptTemplate(
    input_variables = ['tema'],
    template = plantilla
)

cadena1 = prompt | modelo1

# %%
modelo2 = ChatOpenAI(model_name='gpt-3.5-turbo', temperature=1.2, max_tokens=1024)
plantilla2 = """
    Necesito que seas un experto guionista y creador de contenido para redes sociales como youtube, necesito 
    que me hagas el script completo para youtube sobre este tema, necesito explicar todo con lujo de detalle:
    {puntos}
"""

# %%
prompt2 = PromptTemplate(
    input_variables = ['puntos'],
    template = plantilla2
)

cadena2 = prompt2 | modelo2

# %%
modelo3 = ChatOpenAI(model_name='gpt-4', temperature=1.2, max_tokens=1024)
plantilla3 = '''
    Necesito que seas un experto en SEO, necesito que bajo todo el conocimiento de Youtube que tienes me
    hagas un titulo (100 caracteres incluyendo espacios) y una descripcion (entre 4000 a 5000 caracteres)
    , no anotes los numeros de caracteres, para el script anterior. Que el titulo este en forma de pregunta
    con base a como por ejemplo: ¿cómo vender mas? {script}
'''

# %%
prompt3 = PromptTemplate(
    input_variables = ['script'],
    template = plantilla3
)

cadena3 = prompt3 | modelo3

# %%
chainFin = (RunnablePassthrough()
    .assign(puntos = cadena1)
    .assign(script = cadena2)
    .assign(resultadoFinal = cadena3)
)

# %%
resultado = chainFin.invoke({"tema": 'Ingenieria de Datos'})

print("PUNTOS:\n", resultado["puntos"].content)
print("\nSCRIPT:\n", resultado["script"].content)
print("\nSEO FINAL:\n", resultado["resultadoFinal"].content)
# Out:
# PUNTOS:
#  1. Recolección de datos: Es fundamental contar con un proceso eficiente y confiable para la recolección de datos de diversas fuentes, como bases de datos, archivos, APIs, sensores, redes sociales, entre otros.
#
# 2. Almacenamiento de datos: Se deben utilizar sistemas de almacenamiento adecuados para gestionar grandes volúmenes de datos de forma eficiente, como bases de datos relacionales, bases de datos NoSQL, data lakes, entre otros.
#
# 3. Procesamiento de datos: Es importante contar con herramientas y técnicas para procesar y transformar los datos de manera eficiente, como ETL (Extract, Transform, Load), procesamiento en tiempo real, procesamiento distribuido, entre otros.
#
# 4. Limpieza y calidad de datos: La limpieza y la calidad de los datos son aspectos fundamentales para garantizar la integridad y confiabilidad de la información. Se deben aplicar técnicas de limpieza, normalización y validación de datos.
#
# 5. Análisis de datos: Se deben utilizar técnicas de análisis de datos, como minería de datos, análisis estadístico, machine learning, para extraer información valiosa y tomar decisiones basadas en datos.
#
# 6. Visualización de datos: Es importante contar con herramientas de visualización de datos para representar la información de forma clara y comprensible, facilitando la toma de decisiones.
#
# 7. Seguridad de datos: Se deben implementar medidas de seguridad para proteger los datos de accesos no autorizados, como cifrado de datos, control de accesos, auditorías de seguridad, entre otros.
#
# 8. Cumplimiento normativo: Es fundamental cumplir con las regulaciones y normativas relacionadas con la privacidad y protección de datos, como el RGPD en Europa o la Ley de Protección de Datos Personales en México.
#
# 9. Escalabilidad y rendimiento: Se deben diseñar soluciones escalables y eficientes para gestionar grandes volúmenes de datos y garantizar un buen rendimiento en el procesamiento y análisis de la información.
#
# 10. Colaboración interdisciplinaria: La Ingeniería de Datos es un campo multidisciplinario que requiere la colaboración entre ingenieros, científicos de datos, analistas de negocios, entre otros, para desarrollar soluciones efectivas y satisfacer las necesidades de la organización.
#
# SCRIPT:
#  ¡Claro! A continuación te presento el script completo para tu video de YouTube sobre el tema de Ingeniería de Datos:
#
# [INTRODUCCIÓN]
# Hola a todos, en el día de hoy vamos a hablar sobre un tema cada vez más importante en el mundo de la tecnología y los negocios: la Ingeniería de Datos.
#
# [1. Recolección de datos]
# El primer paso en el proceso de Ingeniería de Datos es la recolección de datos. Es fundamental contar con un proceso eficiente y confiable para obtener información de diversas fuentes como bases de datos, archivos, APIs, sensores y redes sociales.
#
# [2. Almacenamiento de datos]
# Una vez que tenemos los datos, es crucial almacenarlos de manera adecuada para gestionar grandes volúmenes de información. Entre las opciones disponibles se encuentran bases de datos relacionales, bases de datos NoSQL y data lakes.
#
# [3. Procesamiento de datos]
# Contar con herramientas y técnicas para procesar y transformar los datos de forma eficiente es esencial. El uso de tecnologías como ETL, procesamiento en tiempo real y procesamiento distribuido permiten optimizar este proceso.
#
# [4. Limpieza y calidad de datos]
# La limpieza y la calidad de los datos son aspectos clave para garantizar la integridad y fiabilidad de la información. Aplicar técnicas de limpieza, normalización y validación es fundamental en este sentido.
#
# [5. Análisis de datos]
# Utilizar técnicas como minería de datos, análisis estadístico y machine learning nos permite extraer información valiosa y tomar decisiones fundamentadas en los datos recopilados.
#
# [6. Visualización de datos]
# Contar con herramientas de visualización de datos facilita la representación de la información de forma clara y comprensible, lo que a su vez favorece la toma de decisiones informadas.
#
# [7. Seguridad de datos]
# Implementar medidas de seguridad como el cifrado de datos, el control de accesos y las auditorías de seguridad es esencial para proteger la información contra accesos no autorizados.
#
# [8. Cumplimiento normativo]
# Es fundamental cumplir con las regulaciones y normativas en materia de privacidad y protección de datos, como el RGPD en Europa o la Ley de Protección de Datos Personales en México.
#
# [9. Escalabilidad y rendimiento]
# Diseñar soluciones escalables y eficientes es fundamental para gestionar grandes volúmenes de datos y garantizar un buen rendimiento en su procesamiento y análisis.
#
# [10. Colaboración interdisciplinaria]
# La Ingeniería de Datos es un campo multidisciplinario que requiere la colaboración entre diferentes profesionales como ingenieros, científicos de datos y analistas de negocios para desarrollar soluciones efectivas que satisfagan las necesidades de la organización.
#
# [CONCLUSIÓN]
# En resumen, la Ingeniería de Datos es un proceso fundamental en el mundo actual, que nos permite aprovechar la información de manera eficiente para tomar decisiones informadas y estratégicas. ¡Espero que este video te haya sido de utilidad! ¡Hasta la próxima!
#
# Espero que este guion te ayude a crear un video completo y detallado sobre el apasionante tema de la Ingeniería de Datos. ¡Mucho éxito en tu proyecto!
#
# SEO FINAL:
#  Título: ¿Cómo se gestiona la información a través de la Ingeniería de Datos?
#
# Descripción: ¡Bienvenidos a nuestra charla sobre la importancia de la Ingeniería de Datos en el manejo efectivo de la información! La incorporación cada vez mayor de la toma de decisiones basada en datos en la estrategia de las empresas modernas ha convertido a la Ingeniería de Datos en un componente vital en la industria de la tecnología y los negocios. En este video, vamos a hablar sobre los distintos visiones de la Ingeniería de Datos, que incluyen la recolección, almacenamiento, procesamiento, limpieza y la calidad de datos, análisis y visualización de datos, seguridad de datos, cumplimiento normativo, escalabilidad y rendimiento, y cómo estas actividades están vinculadas entre sí. Aprenderá las técnicas, herramientas y normativas que le permitirán optimizar estos procesos e implementar estrategias multidisciplinarias efectivas para resolver problemas complejos en su organización. Juntos, vamos a profundizar en cada una de estas etapas y explorar las mejores prácticas para lograr una excelente ingeniería de datos. ¡No se pierda la posibilidad de usar este flujo de trabajo sencillo de Ingeniería de Datos para tomar las decisiones más informadas posible y convertir los datos recopilados en ideas significativas y accionables! Este video no solo le proporcionará un conocimiento en Ingeniería de Datos, sino también habilidades esenciales en la era de la digitalización acelerada. ¡No espere más y comience este viaje de descubrimiento de aumento de eficiencia en la gestión de la información YA!

# %%
#Agentes LangChain

# %%
from langchain.agents import create_agent
from langchain_experimental.tools import PythonREPLTool
from langchain_openai import ChatOpenAI

# %%
modelo = ChatOpenAI(
    model = 'gpt-4o-mini',
    temperature=0)

# %%
print(modelo)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x00000269B8474410> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000269B81B30E0> root_client=<openai.OpenAI object at 0x00000269B8645A90> root_async_client=<openai.AsyncOpenAI object at 0x00000269B9DCB740> model_name='gpt-4o-mini' temperature=0.0 model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
agenteEjecutor = create_agent(
    model = modelo,
    tools=[PythonREPLTool()]
)

# %%
agenteEjecutor.invoke(
    {'messages':[
        {'role':'user', 'content':'Cual es el resultado de pi elevado a la 5 solo sus primeros 10 decimales'}
    ]}
)
# Out:
# Python REPL can execute arbitrary code. Use with caution.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 agenteEjecutor.invoke(
#       2     {'messages':[
#       3         {'role':'user', 'content':'Cual es el resultado de pi elevado a la 5 solo sus primeros 10 decimales'}
#       4     ]}
#       5 )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\pregel\main.py:3071, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3068 chunks: list[dict[str, Any] | Any] = []
#    3069 interrupts: list[Interrupt] = []
# -> 3071 for chunk in self.stream(
#    3072     input,
#    3073     config,
#    3074     context=context,
#    3075     stream_mode=["updates", "values"]
#    3076     if stream_mode == "values"
#    3077     else stream_mode,
#    3078     print_mode=print_mode,
#    3079     output_keys=output_keys,
#    3080     interrupt_before=interrupt_before,
#    3081     interrupt_after=interrupt_after,
#    3082     durability=durability,
#    3083     **kwargs,
#    3084 ):
#    3085     if stream_mode == "values":
#    3086         if len(chunk) == 2:
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\pregel\main.py:2646, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2644 for task in loop.match_cached_writes():
#    2645     loop.output_writes(task.id, task.writes, cached=True)
# -> 2646 for _ in runner.tick(
#    2647     [t for t in loop.tasks.values() if not t.writes],
#    2648     timeout=self.step_timeout,
#    2649     get_waiter=get_waiter,
#    2650     schedule_task=loop.accept_push,
#    2651 ):
#    2652     # emit output
#    2653     yield from _output(
#    2654         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2655     )
#    2656 loop.after_tick()
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain\agents\factory.py:1261, in create_agent.<locals>.model_node(state, runtime)
#    1249 request = ModelRequest(
#    1250     model=model,
#    1251     tools=default_tools,
#    (...)   1257     runtime=runtime,
#    1258 )
#    1260 if wrap_model_call_handler is None:
# -> 1261     model_response = _execute_model_sync(request)
#    1262     return _build_commands(model_response)
#    1264 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain\agents\factory.py:1233, in create_agent.<locals>._execute_model_sync(request)
#    1230 if request.system_message:
#    1231     messages = [request.system_message, *messages]
# -> 1233 output = model_.invoke(messages)
#    1234 if name:
#    1235     output.name = name
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\runnables\base.py:5695, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5688 @override
#    5689 def invoke(
#    5690     self,
#    (...)   5693     **kwargs: Any | None,
#    5694 ) -> Output:
# -> 5695     return self.bound.invoke(
#    5696         input,
#    5697         self._merge_configs(config),
#    5698         **{**self.kwargs, **kwargs},
#    5699     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_openai\chat_models\base.py:1473, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1471     _handle_openai_bad_request(e)
#    1472 except openai.APIError as e:
# -> 1473     _handle_openai_api_error(e)
#    1474 except Exception as e:
#    1475     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\langchain_openai\chat_models\base.py:1468, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1461         return _construct_lc_result_from_responses_api(
#    1462             response,
#    1463             schema=original_schema_obj,
#    1464             metadata=generation_info,
#    1465             output_version=self.output_version,
#    1466         )
#    1467     else:
# -> 1468         raw_response = self.client.with_raw_response.create(**payload)
#    1469         response = raw_response.parse()
#    1470 except openai.BadRequestError as e:
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\resources\chat\completions\completions.py:1204, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1157 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1158 def create(
#    1159     self,
#    (...)   1201     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1202 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1203     validate_response_format(response_format)
# -> 1204     return self._post(
#    1205         "/chat/completions",
#    1206         body=maybe_transform(
#    1207             {
#    1208                 "messages": messages,
#    1209                 "model": model,
#    1210                 "audio": audio,
#    1211                 "frequency_penalty": frequency_penalty,
#    1212                 "function_call": function_call,
#    1213                 "functions": functions,
#    1214                 "logit_bias": logit_bias,
#    1215                 "logprobs": logprobs,
#    1216                 "max_completion_tokens": max_completion_tokens,
#    1217                 "max_tokens": max_tokens,
#    1218                 "metadata": metadata,
#    1219                 "modalities": modalities,
#    1220                 "n": n,
#    1221                 "parallel_tool_calls": parallel_tool_calls,
#    1222                 "prediction": prediction,
#    1223                 "presence_penalty": presence_penalty,
#    1224                 "prompt_cache_key": prompt_cache_key,
#    1225                 "prompt_cache_retention": prompt_cache_retention,
#    1226                 "reasoning_effort": reasoning_effort,
#    1227                 "response_format": response_format,
#    1228                 "safety_identifier": safety_identifier,
#    1229                 "seed": seed,
#    1230                 "service_tier": service_tier,
#    1231                 "stop": stop,
#    1232                 "store": store,
#    1233                 "stream": stream,
#    1234                 "stream_options": stream_options,
#    1235                 "temperature": temperature,
#    1236                 "tool_choice": tool_choice,
#    1237                 "tools": tools,
#    1238                 "top_logprobs": top_logprobs,
#    1239                 "top_p": top_p,
#    1240                 "user": user,
#    1241                 "verbosity": verbosity,
#    1242                 "web_search_options": web_search_options,
#    1243             },
#    1244             completion_create_params.CompletionCreateParamsStreaming
#    1245             if stream
#    1246             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1247         ),
#    1248         options=make_request_options(
#    1249             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1250         ),
#    1251         cast_to=ChatCompletion,
#    1252         stream=stream or False,
#    1253         stream_cls=Stream[ChatCompletionChunk],
#    1254     )
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\OD\OneDrive - TI\Documentos\Sebastian Carrero\programacion2026\entornosPy\entornoPrueba\Lib\site-packages\openai\_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-F5uhYsHFGHRIedWJEveAxIaJ on tokens per min (TPM): Limit 200000, Used 200000, Requested 882. Please try again in 264ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# During task with name 'model' and id 'a101d744-28b6-6e6b-4921-f3443c69ea66'
