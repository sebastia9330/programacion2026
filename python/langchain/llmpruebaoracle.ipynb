# %%
# ✅ Conexión y carga de datos bloque1
print("✅ Conectando a Oracle...")
conn_str = (
    "oracle://WORK_ODS:Cambio2025*@157.137.227.142:1521/"
    "DBIA_pdb1.subnetbd.vcnitservicesco.oraclevcn.com"
)
